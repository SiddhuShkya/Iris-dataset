# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head(10)
# Out:
#    Id  sep-len  sep-wid  pet-len  pet-wid      Species
# 0   1      5.1      3.5      1.4      0.2  Iris-setosa
# 1   2      4.9      3.0      1.4      0.2  Iris-setosa
# 2   3      4.7      3.2      1.3      0.2  Iris-setosa
# 3   4      4.6      3.1      1.5      0.2  Iris-setosa
# 4   5      5.0      3.6      1.4      0.2  Iris-setosa
# 5   6      5.4      3.9      1.7      0.4  Iris-setosa
# 6   7      4.6      3.4      1.4      0.3  Iris-setosa
# 7   8      5.0      3.4      1.5      0.2  Iris-setosa
# 8   9      4.4      2.9      1.4      0.2  Iris-setosa
# 9  10      4.9      3.1      1.5      0.1  Iris-setosa

# %%
df.tail()
# Out:
#       Id  sep-len  sep-wid  pet-len  pet-wid         Species
# 145  146      6.7      3.0      5.2      2.3  Iris-virginica
# 146  147      6.3      2.5      5.0      1.9  Iris-virginica
# 147  148      6.5      3.0      5.2      2.0  Iris-virginica
# 148  149      6.2      3.4      5.4      2.3  Iris-virginica
# 149  150      5.9      3.0      5.1      1.8  Iris-virginica

# %%
df = df.drop(columns='Id')

# %%
df.head()
# Out:
#    sep-len  sep-wid  pet-len  pet-wid      Species
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sep-len  150 non-null    float64
#  1   sep-wid  150 non-null    float64
#  2   pet-len  150 non-null    float64
#  3   pet-wid  150 non-null    float64
#  4   Species  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sep-len    0
# sep-wid    0
# pet-len    0
# pet-wid    0
# Species    0
# dtype: int64

# %%
df.describe()
# Out:
#           sep-len     sep-wid     pet-len     pet-wid
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.plot(kind='scatter',x='sep-len',y='sep-wid')
# Out:
# <AxesSubplot:xlabel='sep-len', ylabel='sep-wid'>

# %%
df.plot(kind='scatter',x='pet-len',y='pet-wid')
# Out:
# <AxesSubplot:xlabel='pet-len', ylabel='pet-wid'>

# %%
sns.pairplot(df, hue='Species')

# %%
sns.factorplot('sep-len',data=df,hue='Species',kind='count',size=10)

# %%
sns.factorplot('sep-wid',data=df,hue='Species',kind='count',size=10)

# %%
sns.factorplot('pet-len',data=df,hue='Species',kind='count',size=10)

# %%
sns.factorplot('pet-wid',data=df,hue='Species',kind='count',size=10)

# %%
from pandas.plotting import andrews_curves
andrews_curves(df,'Species')
# Out:
# <AxesSubplot:>

# %%
sns.FacetGrid(df, hue='Species',size=8)\
.map(plt.scatter,'sep-len','sep-wid')\
.add_legend()

# %%
sns.FacetGrid(df, hue='Species',size=8)\
.map(plt.scatter,'pet-len','pet-wid')\
.add_legend()

# %%
df.hist(edgecolor='black', linewidth=1.2)
fig = plt.gcf()
fig.set_size_inches(12,6)

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#           sep-len   sep-wid   pet-len   pet-wid
# sep-len  1.000000 -0.109369  0.871754  0.817954
# sep-wid -0.109369  1.000000 -0.420516 -0.356544
# pet-len  0.871754 -0.420516  1.000000  0.962757
# pet-wid  0.817954 -0.356544  0.962757  1.000000

# %%
df.corr()['sep-len'].sort_values()
# Out:
# sep-wid   -0.109369
# pet-wid    0.817954
# pet-len    0.871754
# sep-len    1.000000
# Name: sep-len, dtype: float64

# %%
df.corr()['sep-wid'].sort_values()
# Out:
# pet-len   -0.420516
# pet-wid   -0.356544
# sep-len   -0.109369
# sep-wid    1.000000
# Name: sep-wid, dtype: float64

# %%
df.corr()['pet-len'].sort_values()
# Out:
# sep-wid   -0.420516
# sep-len    0.871754
# pet-wid    0.962757
# pet-len    1.000000
# Name: pet-len, dtype: float64

# %%
df.corr()['pet-wid'].sort_values()
# Out:
# sep-wid   -0.356544
# sep-len    0.817954
# pet-len    0.962757
# pet-wid    1.000000
# Name: pet-wid, dtype: float64

# %% [markdown]
# # Splitting the data into training and testing set

# %%
from sklearn.model_selection import train_test_split as tts
train,test = tts(df, test_size=0.2, random_state=20)

# %%
print(train.shape)
# Out:
# (120, 5)

# %%
print(test.shape)
# Out:
# (30, 5)

# %%
train_x = train[['sep-len','sep-wid','pet-len','pet-wid']]
train_x
# Out:
#      sep-len  sep-wid  pet-len  pet-wid
# 95       5.7      3.0      4.2      1.2
# 88       5.6      3.0      4.1      1.3
# 0        5.1      3.5      1.4      0.2
# 46       5.1      3.8      1.6      0.2
# 11       4.8      3.4      1.6      0.2
# ..       ...      ...      ...      ...
# 22       4.6      3.6      1.0      0.2
# 75       6.6      3.0      4.4      1.4
# 137      6.4      3.1      5.5      1.8
# 15       5.7      4.4      1.5      0.4
# 99       5.7      2.8      4.1      1.3
#
# [120 rows x 4 columns]

# %%
train_y = train.Species
train_y
# Out:
# 95     Iris-versicolor
# 88     Iris-versicolor
# 0          Iris-setosa
# 46         Iris-setosa
# 11         Iris-setosa
#             ...
# 22         Iris-setosa
# 75     Iris-versicolor
# 137     Iris-virginica
# 15         Iris-setosa
# 99     Iris-versicolor
# Name: Species, Length: 120, dtype: object

# %%
test_x = test[['sep-len','sep-wid','pet-len','pet-wid']]
test_y = test.Species

# %%
print(test_x)
# Out:
#      sep-len  sep-wid  pet-len  pet-wid
# 47       4.6      3.2      1.4      0.2
# 73       6.1      2.8      4.7      1.2
# 74       6.4      2.9      4.3      1.3
# 129      7.2      3.0      5.8      1.6
# 67       5.8      2.7      4.1      1.0
# 89       5.5      2.5      4.0      1.3
# 143      6.8      3.2      5.9      2.3
# 21       5.1      3.7      1.5      0.4
# 108      6.7      2.5      5.8      1.8
# 12       4.8      3.0      1.4      0.1
# 147      6.5      3.0      5.2      2.0
# 76       6.8      2.8      4.8      1.4
# 119      6.0      2.2      5.0      1.5
# 35       5.0      3.2      1.2      0.2
# 28       5.2      3.4      1.4      0.2
# 122      7.7      2.8      6.7      2.0
# 13       4.3      3.0      1.1      0.1
# 58       6.6      2.9      4.6      1.3
# 114      5.8      2.8      5.1      2.4
# 57       4.9      2.4      3.3      1.0
# 50       7.0      3.2      4.7      1.4
# 149      5.9      3.0      5.1      1.8
# 111      6.4      2.7      5.3      1.9
# 20       5.4      3.4      1.7      0.2
# 72       6.3      2.5      4.9      1.5
# 81       5.5      2.4      3.7      1.0
# 98       5.1      2.5      3.0      1.1
# 34       4.9      3.1      1.5      0.1
# 104      6.5      3.0      5.8      2.2
# 133      6.3      2.8      5.1      1.5

# %%
print(test_y)
# Out:
# 47         Iris-setosa
# 73     Iris-versicolor
# 74     Iris-versicolor
# 129     Iris-virginica
# 67     Iris-versicolor
# 89     Iris-versicolor
# 143     Iris-virginica
# 21         Iris-setosa
# 108     Iris-virginica
# 12         Iris-setosa
# 147     Iris-virginica
# 76     Iris-versicolor
# 119     Iris-virginica
# 35         Iris-setosa
# 28         Iris-setosa
# 122     Iris-virginica
# 13         Iris-setosa
# 58     Iris-versicolor
# 114     Iris-virginica
# 57     Iris-versicolor
# 50     Iris-versicolor
# 149     Iris-virginica
# 111     Iris-virginica
# 20         Iris-setosa
# 72     Iris-versicolor
# 81     Iris-versicolor
# 98     Iris-versicolor
# 34         Iris-setosa
# 104     Iris-virginica
# 133     Iris-virginica
# Name: Species, dtype: object

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(train_x,train_y)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(test_x)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,test_y)*100
# Out:
# 93.33333333333333

# %%
comp_df = pd.DataFrame()
comp_df['Actual Species']=test_y
comp_df['Predicted Species']=y_pred

# %%
comp_df.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(test_x)

# %%
accuracy_score(y_pred,test_y)*100
# Out:
# 93.33333333333333

# %%
comp_df = pd.DataFrame()
comp_df['Actual Species']=test_y
comp_df['Predicted Species']=y_pred

# %%
comp_df.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm

# %%
model = svm.SVC()

# %%
model.fit(train_x,train_y)
# Out:
# SVC()

# %%
y_pred = model.predict(test_x)

# %%
accuracy_score(y_pred,test_y)*100
# Out:
# 100.0

# %%
comp_df = pd.DataFrame()
comp_df['Actual Species']=test_y
comp_df['Predicted Species']=y_pred

# %%
comp_df.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica    Iris-virginica
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %% [markdown]
# # Creating Petals and Sepals Training data

# %%
sepal=df[['sep-len','sep-wid','Species']]
petal=df[['pet-len','pet-wid','Species']]

# %%
#For iris sepal
train_s,test_s = tts(sepal,test_size=0.3,random_state=20)

# %%
train_x_s = train_s[['sep-len','sep-wid']]
test_x_s = test_s[['sep-len','sep-wid']]
test_x_s.shape
# Out:
# (45, 2)

# %%
train_y_s = train_s.Species
test_y_s = test_s.Species
test_y_s.shape
# Out:
# (45,)

# %%
#For iris petal
train_p,test_p = tts(petal, test_size=0.3, random_state=20)

# %%
train_x_p = train_p[['pet-len','pet-wid']]
test_x_p = test_p[['pet-len','pet-wid']]
test_x_p.shape
# Out:
# (45, 2)

# %%
train_y_p = train_p.Species
test_y_p = test_p.Species
test_y_p.shape
# Out:
# (45,)

# %% [markdown]
# # Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(train_x_s,train_y_s)
# Out:
# LogisticRegression()

# %%
prediction = model.predict(test_x_s)
print('The accuracy of the Logistic Regression using seplas is: ',accuracy_score(prediction,test_y_s)*100)
# Out:
# The accuracy of the Logistic Regression using seplas is:  71.11111111111111

# %%
comp_df_sep = pd.DataFrame()
comp_df_sep['Actual Species'] = test_y_s
comp_df_sep['Predicted Species'] = prediction
comp_df_sep.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor    Iris-virginica
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor    Iris-virginica
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %%
model.fit(train_x_p,train_y_p)
# Out:
# LogisticRegression()

# %%
prediction = model.predict(test_x_p)
print('The accuracy of the Logistic Regression using petals is: ',accuracy_score(prediction,test_y_p)*100)
# Out:
# The accuracy of the Logistic Regression using petals is:  93.33333333333333

# %%
comp_df_pet = pd.DataFrame()
comp_df_pet['Actual Species'] = test_y_p
comp_df_pet['Predicted Species'] = prediction
comp_df_pet.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %% [markdown]
# # Decision Tree

# %%
model = DecisionTreeClassifier()

# %%
model.fit(train_x_s,train_y_s)
# Out:
# DecisionTreeClassifier()

# %%
prediction = model.predict(test_x_s)
print('The accuracy of the Decision Tree using sepals is: ',accuracy_score(prediction,test_y_s)*100)
# Out:
# The accuracy of the Decision Tree using sepals is:  71.11111111111111

# %%
comp_df_sep = pd.DataFrame()
comp_df_sep['Actual Species'] = test_y_s
comp_df_sep['Predicted Species'] = prediction
comp_df_sep.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor    Iris-virginica
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor    Iris-virginica
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica   Iris-versicolor
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor    Iris-virginica
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %%
model.fit(train_x_p,train_y_p)
# Out:
# DecisionTreeClassifier()

# %%
prediction = model.predict(test_x_p)
print('The accuracy of the Decision Tree using petals is: ',accuracy_score(prediction,test_y_p)*100)
# Out:
# The accuracy of the Decision Tree using petals is:  88.88888888888889

# %%
comp_df_pet = pd.DataFrame()
comp_df_pet['Actual Species'] = test_y_p
comp_df_pet['Predicted Species'] = prediction
comp_df_pet.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica   Iris-versicolor
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %% [markdown]
# # K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(train_x_s,train_y_s)
# Out:
# KNeighborsClassifier()

# %%
prediction = model.predict(test_x_s)
print('The accuracy of the KNN using sepals is : ',accuracy_score(prediction,test_y_s)*100)
# Out:
# The accuracy of the KNN using sepals is :  73.33333333333333

# %%
comp_df_sep = pd.DataFrame()
comp_df_sep['Actual Species'] = test_y_s
comp_df_sep['Predicted Species'] = prediction
comp_df_sep.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor    Iris-virginica
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %%
model.fit(train_x_p,train_y_p)
# Out:
# KNeighborsClassifier()

# %%
prediction = model.predict(test_x_p)
print('The accuracy of the KNN using petals is : ',accuracy_score(prediction,test_y_p)*100)
# Out:
# The accuracy of the KNN using petals is :  93.33333333333333

# %%
comp_df_pet = pd.DataFrame()
comp_df_pet['Actual Species'] = test_y_p
comp_df_pet['Predicted Species'] = prediction
comp_df_pet.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %% [markdown]
# # Support Vector Machine

# %%
model = svm.SVC()

# %%
model.fit(train_x_s,train_y_s)
# Out:
# SVC()

# %%
prediction = model.predict(test_x_s)
print('The accuracy of SVM using sepals is : ',accuracy_score(prediction,test_y_s)*100)
# Out:
# The accuracy of SVM using sepals is :  71.11111111111111

# %%
comp_df_sep = pd.DataFrame()
comp_df_sep['Actual Species'] = test_y_s
comp_df_sep['Predicted Species'] = prediction
comp_df_sep.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor    Iris-virginica
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor    Iris-virginica
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa

# %%
model.fit(train_x_p,train_y_p)
# Out:
# SVC()

# %%
prediction = model.predict(test_x_p)
print('The accuracy of SVM using petals is : ',accuracy_score(prediction,test_y_p)*100)
# Out:
# The accuracy of SVM using petals is :  95.55555555555556

# %%
comp_df_pet = pd.DataFrame()
comp_df_pet['Actual Species'] = test_y_p
comp_df_pet['Predicted Species'] = prediction
comp_df_pet.head(15)
# Out:
#       Actual Species Predicted Species
# 47       Iris-setosa       Iris-setosa
# 73   Iris-versicolor   Iris-versicolor
# 74   Iris-versicolor   Iris-versicolor
# 129   Iris-virginica    Iris-virginica
# 67   Iris-versicolor   Iris-versicolor
# 89   Iris-versicolor   Iris-versicolor
# 143   Iris-virginica    Iris-virginica
# 21       Iris-setosa       Iris-setosa
# 108   Iris-virginica    Iris-virginica
# 12       Iris-setosa       Iris-setosa
# 147   Iris-virginica    Iris-virginica
# 76   Iris-versicolor   Iris-versicolor
# 119   Iris-virginica   Iris-versicolor
# 35       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa
